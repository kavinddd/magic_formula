# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from selenium import webdriver

# %% [markdown]
# # Web scraping

# %% [markdown]
# ## Stock names
# Take all the name of stocks from siamchart

# %%
url = 'http://siamchart.com/stock-financial/'
html = requests.get(url).text
soup = BeautifulSoup(html)
tag_a= soup.find_all('a')
stocks_name = [tag_a[i].text.split('(')[0] for i in range(21,len(tag_a))]
print(stocks_name)
# Out:
# ['24CS', '2S', '3K-BAT', '7UP', 'A', 'A5', 'AAI', 'AAV', 'ABICO', 'ABM', 'ACAP', 'ACC', 'ACE', 'ACG', 'ADB', 'ADD', 'ADVANC', 'AEONTS', 'AF', 'AFC', 'AGE', 'AH', 'AHC', 'AI', 'AIE', 'AIRA', 'AIT', 'AJ', 'AJA', 'AKP', 'AKR', 'ALL', 'ALLA', 'ALPHAX', 'ALT', 'ALUCON', 'AMA', 'AMANAH', 'AMARC', 'AMARIN', 'AMATA', 'AMATAV', 'AMC', 'AMR', 'ANAN', 'AOT', 'AP', 'APCO', 'APCS', 'APEX', 'APP', 'APURE', 'AQ', 'AQUA', 'ARIN', 'ARIP', 'ARROW', 'AS', 'ASAP', 'ASEFA', 'ASIA', 'ASIAN', 'ASIMAR', 'ASK', 'ASN', 'ASP', 'ASW', 'ATP30', 'AU', 'AUCT', 'AWC', 'AYUD', 'B', 'B52', 'BA', 'BAFS', 'BAM', 'BANPU', 'BAY', 'BBGI', 'BBIK', 'BBL', 'BC', 'BCH', 'BCP', 'BCPG', 'BCT', 'BDMS', 'BE8', 'BEAUTY', 'BEC', 'BEM', 'BEYOND', 'BFIT', 'BGC', 'BGRIM', 'BGT', 'BH', 'BIG', 'BIOTEC', 'BIS', 'BIZ', 'BJC', 'BJCHI', 'BKD', 'BKI', 'BLA', 'BLAND', 'BLESS', 'BLISS', 'BM', 'BOL', 'BPP', 'BR', 'BRI', 'BROCK', 'BROOK', 'BRR', 'BSBM', 'BSM', 'BTG', 'BTNC', 'BTS', 'BTW', 'BUI', 'BWG', 'BYD', 'CAZ', 'CBG', 'CCET', 'CCP', 'CEN', 'CENTEL', 'CEYE', 'CFRESH', 'CGD', 'CGH', 'CH', 'CHARAN', 'CHAYO', 'CHEWA', 'CHG', 'CHIC', 'CHO', 'CHOTI', 'CHOW', 'CI', 'CIG', 'CIMBT', 'CITY', 'CIVIL', 'CK', 'CKP', 'CM', 'CMAN', 'CMC', 'CMO', 'CMR', 'CNT', 'COLOR', 'COM7', 'COMAN', 'COTTO', 'CPALL', 'CPANEL', 'CPF', 'CPH', 'CPI', 'CPL', 'CPN', 'CPR', 'CPT', 'CPW', 'CRANE', 'CRC', 'CRD', 'CSC', 'CSP', 'CSR', 'CSS', 'CTW', 'CV', 'CWT', 'D', 'DCC', 'DCON', 'DDD', 'DELTA', 'DEMCO', 'DHOUSE', 'DIMET', 'DITTO', 'DMT', 'DOD', 'DOHOME', 'DPAINT', 'DRT', 'DTAC', 'DTCI', 'DUSIT', 'DV8', 'EA', 'EASON', 'EASTW', 'ECF', 'ECL', 'EE', 'EFORL', 'EGCO', 'EKH', 'EMC', 'EP', 'EPG', 'ERW', 'ESSO', 'ESTAR', 'ETC', 'ETE', 'EVER', 'F&D', 'FANCY', 'FE', 'FLOYD', 'FMT', 'FN', 'FNS', 'FORTH', 'FPI', 'FPT', 'FSMART', 'FSS', 'FTE', 'FTI', 'FVC', 'GBX', 'GC', 'GCAP', 'GEL', 'GENCO', 'GFPT', 'GGC', 'GIFT', 'GJS', 'GL', 'GLAND', 'GLOBAL', 'GLOCON', 'GLORY', 'GPI', 'GPSC', 'GRAMMY', 'GRAND', 'GREEN', 'GSC', 'GSTEEL', 'GTB', 'GULF', 'GUNKUL', 'GYT', 'HANA', 'HARN', 'HEMP', 'HENG', 'HFT', 'HL', 'HMPRO', 'HPT', 'HTC', 'HTECH', 'HUMAN', 'HYDRO', 'ICC', 'ICHI', 'ICN', 'IFEC', 'IFS', 'IHL', 'IIG', 'III', 'ILINK', 'ILM', 'IMH', 'IND', 'INET', 'INGRS', 'INOX', 'INSET', 'INSURE', 'INTUCH', 'IP', 'IRC', 'IRCP', 'IRPC', 'IT', 'ITD', 'ITEL', 'ITNS', 'IVL', 'J', 'JAK', 'JAS', 'JCK', 'JCKH', 'JCT', 'JDF', 'JKN', 'JMART', 'JMT', 'JP', 'JR', 'JSP', 'JTS', 'JUBILE', 'JWD', 'K', 'KAMART', 'KASET', 'KBANK', 'KBS', 'KC', 'KCAR', 'KCC', 'KCE', 'KCM', 'KDH', 'KEX', 'KGI', 'KIAT', 'KISS', 'KK', 'KKC', 'KKP', 'KOOL', 'KSL', 'KTB', 'KTC', 'KTIS', 'KUMWEL', 'KUN', 'KWC', 'KWI', 'KWM', 'KYE', 'L&E', 'LALIN', 'LANNA', 'LDC', 'LEE', 'LEO', 'LH', 'LHFG', 'LHK', 'LIT', 'LOXLEY', 'LPH', 'LPN', 'LRH', 'LST', 'M', 'M-CHAI', 'MACO', 'MAJOR', 'MAKRO', 'MALEE', 'MANRIN', 'MATCH', 'MATI', 'MAX', 'MBAX', 'MBK', 'MC', 'MCOT', 'MCS', 'MDX', 'MEGA', 'MENA', 'META', 'METCO', 'MFC', 'MFEC', 'MGT', 'MICRO', 'MIDA', 'MILL', 'MINT', 'MITSIB', 'MJD', 'MK', 'ML', 'MODERN', 'MONO', 'MOONG', 'MORE', 'MPIC', 'MSC', 'MST', 'MTC', 'MTI', 'MUD', 'MVP', 'NATION', 'NBC', 'NC', 'NCAP', 'NCH', 'NCL', 'NDR', 'NEP', 'NER', 'NETBAY', 'NEW', 'NEWS', 'NEX', 'NFC', 'NINE', 'NKI', 'NNCL', 'NOBLE', 'NOK', 'NOVA', 'NPK', 'NRF', 'NSI', 'NSL', 'NTV', 'NUSA', 'NV', 'NVD', 'NWR', 'NYT', 'OCC', 'OGC', 'OHTL', 'OISHI', 'ONEE', 'OR', 'ORI', 'OSP', 'OTO', 'PACE', 'PACO', 'PAE', 'PAF', 'PAP', 'PATO', 'PB', 'PCC', 'PCSGH', 'PDG', 'PDJ', 'PE', 'PEACE', 'PERM', 'PF', 'PG', 'PHOL', 'PICO', 'PIMO', 'PIN', 'PJW', 'PK', 'PL', 'PLANB', 'PLANET', 'PLAT', 'PLE', 'PLUS', 'PM', 'PMTA', 'POLAR', 'PORT', 'POST', 'PPM', 'PPP', 'PPPM', 'PPS', 'PR9', 'PRAKIT', 'PRAPAT', 'PREB', 'PRECHA', 'PRG', 'PRIME', 'PRIN', 'PRINC', 'PRM', 'PRO', 'PROEN', 'PROS', 'PROUD', 'PSG', 'PSH', 'PSL', 'PSTC', 'PT', 'PTC', 'PTECH', 'PTG', 'PTL', 'PTT', 'PTTEP', 'PTTGC', 'PYLON', 'Q-CON', 'QH', 'QLT', 'QTC', 'RAM', 'RATCH', 'RBF', 'RCL', 'RICHY', 'RJH', 'RML', 'ROCK', 'ROH', 'ROJNA', 'RP', 'RPC', 'RPH', 'RS', 'RSP', 'RT', 'RWI', 'S', 'S&J', ' ...

# %% [markdown]
# ## Scraping Industry and Market Cap of each stock
# Scrape these data from SET directly, I scraped them in Thai though

# %%
stocks_info = dict()
for stock in stocks_name:
    if '&' in stock :
        stock_name_temp = stock.replace('&','%26')
    else:
        stock_name_temp = stock

    url = 'https://classic.set.or.th/set/companyprofile.do?symbol='+stock_name_temp+'&ssoPageId=4&language=th&country=TH'
    html = requests.get(url).text
    soup = BeautifulSoup(html)
    inclass = soup.find_all(class_='col-xs-9 col-md-5')
    try:
        marketcap = float(inclass[3].text.replace(',','').strip())
        industry = inclass[5].text
    except:
        continue
    stocks_info[stock] = dict()
    stocks_info[stock]['industry'] = industry
    stocks_info[stock]['marketcap'] = marketcap
# Checking the data
pd.DataFrame(stocks_info).transpose()
# Out:
#                           industry marketcap
# 24CS    อสังหาริมทรัพย์และก่อสร้าง    1788.8
# 2S                สินค้าอุตสาหกรรม   1825.99
# 3K-BAT            สินค้าอุตสาหกรรม    5076.4
# 7UP                       ทรัพยากร   4114.46
# A       อสังหาริมทรัพย์และก่อสร้าง    4880.4
# ...                            ...       ...
# YGG                         บริการ   4876.18
# YONG    อสังหาริมทรัพย์และก่อสร้าง    1400.8
# YUASA             สินค้าอุตสาหกรรม   1506.75
# ZEN        เกษตรและอุตสาหกรรมอาหาร    5070.0
# ZIGA              สินค้าอุตสาหกรรม    3135.8
#
# [777 rows x 2 columns]

# %% [markdown]
# ## Scraping Financial data
# Only those that are needed to be used in calculating magic formula. From this step, we will need selenium library and your browser driver, I use microsoft edge, so I already have the driver in working directory. Since the website that contain this information is dynamic. So, this process will be around a hour. And each website of stocks have patterns which is good, otherwise, it would be impossible to scrape all the stock financial data.

# %%
driver = webdriver.Edge() #เปิด browser ขึ้นมา ใส่ตัวแปร driver เปิดครั้งเดียว
for stock in stocks_name:
    url = 'http://siamchart.com/stock-info/'+stock+'/' #ลิงค์ที่มีงบการเงินอยู่
    driver.get(url) #ให้ browser เปิดลิงค์ url
    html = driver.page_source #ดึง html จากเพจที่เปิดอยู่
    
    # ท่าเดิมครับ
    soup = BeautifulSoup(html)
    # งบไตรมาสล่าสุดอยู่ใน tag td @class = "remove_col"
    tdtag = soup.find_all('td',{'class':'remove_col'})
    
    #ดึงงบแต่ละตัวมาเลย
    #ถ้า error แปลว่า pattern เป็นแบบใน except
    try:
        liability_current = tdtag[85].text.split('(')[0]
        liability_total = tdtag[95].text.split('(')[0]
    except IndexError:
        
        #ถ้า error อีก แปลว่า ไม่มีงบในเว็บนี้
        try:
            ebit = tdtag[12].text.split('(')[0]
            cash = tdtag[18].text.split('(')[0]
            totalasset = tdtag[28].text.split('(')[0]
            liability_current = tdtag[36].text.split('(')[0]
            liability_total = tdtag[40].text.split('(')[0]
        except IndexError: 
            continue 
    ebit = tdtag[30].text.split('(')[0]
    cash = tdtag[45].text.split('(')[0]
    totalasset = tdtag[70].text.split('(')[0]
    
    #เซฟข้อมูลไว้ใน dictionary อันเดิมครับ
    try: #กรณีที่เป็นหุ้นที่ไม่มีในเว็บตลาดหลักทรัพย์ เราทิ้งตัวนั้นไปเลย
        stocks_info[stock]['ebit'] = ebit
        stocks_info[stock]['cash'] = cash
        stocks_info[stock]['totalasset'] = totalasset
        stocks_info[stock]['liability_current'] = liability_current
        stocks_info[stock]['liability_total'] = liability_total
    except KeyError:
        continue
print('Finished!')
# Out:
# Finished!

# %%
# Let's check the data
df = pd.DataFrame(stocks_info).transpose()
display(df.head())
print(f'There are total of stocks that missing data : {df.isna().any(axis=1).sum()}')
print(list(df[df.isna().any(axis=1)].index))# Let's check the data
# Out:
#                           industry marketcap    ebit    cash totalasset  \
# 24CS    อสังหาริมทรัพย์และก่อสร้าง    1788.8     NaN     NaN        NaN
# 2S                สินค้าอุตสาหกรรม   1825.99   -2.34  104.66   2,346.85
# 3K-BAT            สินค้าอุตสาหกรรม    5076.4  100.73  473.39   3,958.31
# 7UP                       ทรัพยากร   4114.46  -68.89   65.64   4,559.75
# A       อสังหาริมทรัพย์และก่อสร้าง    4880.4  300.14  165.19  12,864.62
#
#        liability_current liability_total
# 24CS                 NaN             NaN
# 2S                177.32          212.91
# 3K-BAT            104.88          648.69
# 7UP               141.73          640.67
# A               2,753.20        5,668.22
# There are total of stocks that missing data : 51
# ['24CS', 'AAI', 'AMARC', 'AMR', 'BBGI', 'BIS', 'BLESS', 'BTG', 'CEYE', 'CH', 'CHIC', 'CPANEL', 'DMT', 'F&D', 'FTI', 'GLORY', 'HENG', 'IND', 'ITNS', 'JDF', 'JR', 'JSP', 'KCC', 'KK', 'L&E', 'MENA', 'NSL', 'NV', 'PACO', 'PCC', 'PEACE', 'PIN', 'PLUS', 'PTC', 'SCAP', 'SECURE', 'SFT', 'SICT', 'SO', 'STECH', 'STP', 'SVT', 'TEGH', 'TEKA', 'TGE', 'TIDLOR', 'TIPH', 'TLI', 'TRV', 'WFX', 'YONG']

# %% [markdown]
# What happened after the code above run was there were some stocks have another different pattern which I was unable to identify. But after I look thorugh the website of these stocks, they're all stocks that don't have financial data in siamchart, so I will just drop them.

# %% [markdown]
# ## Cleaning and preparing data
# This process won't take us long, the only problem is that the financial data we collected are actually string not a numeric, so we won't be able to use this data to do calculation. Therefore, we are going to clean the data, only the number will be left, and change the data type to float.

# %%
df= pd.DataFrame(stocks_info).transpose()
# Change order of some columns
df = df.iloc[:, [1,0,2,3,4,5,6]]
# Drop missing data stocks
df = df.dropna()
columns_to_clean = ['ebit','cash','totalasset','liability_current','liability_total']
for column in columns_to_clean:
    df[column] = df[column].str.replace(',','').astype('float')

# %% [markdown]
# # Applying magic formula
# This is an another easy process, all we have to do just make some calculation finding ey and roc, but we have to filter stocks in financial sector out because magic formula won't invest on those.

# %%
# filter financial business out
cleaned_df = df[df['industry'] != 'ธุรกิจการเงิน']

cleaned_df['ey'] = cleaned_df['ebit'] / (cleaned_df['marketcap']+ cleaned_df['liability_total']- cleaned_df['cash'])
cleaned_df['roc'] = cleaned_df['ebit'] / (cleaned_df['totalasset'] - cleaned_df['liability_current'])
cleaned_df.head()
# Out:
# C:\Users\fnvin\AppData\Local\Temp\ipykernel_6324\3293095404.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['ey'] = cleaned_df['ebit'] / (cleaned_df['marketcap']+ cleaned_df['liability_total']- cleaned_df['cash'])
# C:\Users\fnvin\AppData\Local\Temp\ipykernel_6324\3293095404.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['roc'] = cleaned_df['ebit'] / (cleaned_df['totalasset'] - cleaned_df['liability_current'])
#        marketcap                    industry    ebit    cash  totalasset  \
# 2S       1825.99            สินค้าอุตสาหกรรม   -2.34  104.66     2346.85
# 3K-BAT    5076.4            สินค้าอุตสาหกรรม  100.73  473.39     3958.31
# 7UP      4114.46                    ทรัพยากร  -68.89   65.64     4559.75
# A         4880.4  อสังหาริมทรัพย์และก่อสร้าง  300.14  165.19    12864.62
# A5        3337.9  อสังหาริมทรัพย์และก่อสร้าง  112.04  174.25     1527.41
#
#         liability_current  liability_total        ey       roc
# 2S                 177.32           212.91  -0.00121 -0.001079
# 3K-BAT             104.88           648.69   0.01918  0.026140
# 7UP                141.73           640.67  -0.01469 -0.015593
# A                 2753.20          5668.22  0.028906  0.029683
# A5                 179.48           630.20  0.029532  0.083120

# %%
# Sort descdending by ey to do scoring
cleaned_df.sort_values('ey',ascending=False,inplace=True)
cleaned_df['ey_score'] = [x for x in range(1,len(cleaned_df)+1)]
# Sort descending by roc to do scoring
cleaned_df.sort_values('roc',ascending=False,inplace=True)
cleaned_df['roc_score'] = [x for x in range(1,len(cleaned_df)+1)]

# Combining ey_score and roc_score to receive a magic_score
cleaned_df['magic_score'] = cleaned_df[['ey_score','roc_score']].sum(axis=1)
cleaned_df.sort_values('magic_score',inplace = True)

# Top 30 
display(cleaned_df.head(30))
magic_formula = cleaned_df.head(30)
print('Top 30 stocks in magic formula are:')
print(list(magic_formula.index))
# Out:
# C:\Users\fnvin\AppData\Local\Temp\ipykernel_6324\183243455.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df.sort_values('ey',ascending=False,inplace=True)
# C:\Users\fnvin\AppData\Local\Temp\ipykernel_6324\183243455.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['ey_score'] = [x for x in range(1,len(cleaned_df)+1)]
# C:\Users\fnvin\AppData\Local\Temp\ipykernel_6324\183243455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df.sort_values('roc',ascending=False,inplace=True)
# C:\Users\fnvin\AppData\Local\Temp\ipykernel_6324\183243455.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['roc_score'] = [x for x in range(1,len(cleaned_df)+1)]
# C:\Users\fnvin\AppData\Local\Temp\ipykernel_6324\183243455.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['magic_score'] = cleaned_df[['ey_score','roc_score']].sum(axis=1)
# C:\Users\fnvin\AppData\Local\Temp\ipykernel_6324\183243455.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df.sort_values('magic_score',inplace = True)
#         marketcap                    industry       ebit       cash  \
# NATION    1057.67                      บริการ     557.09     146.48
# RCL      23619.38                      บริการ   15704.11   16625.75
# LANNA     9922.49                    ทรัพยากร    4638.13    3211.46
# ECF       1707.89          สินค้าอุปโภคบริโภค     167.95    1314.47
# CHOW       2656.0            สินค้าอุตสาหกรรม    1358.87      31.24
# BTNC        141.6          สินค้าอุปโภคบริโภค     -13.01     240.67
# ESSO     50528.53                    ทรัพยากร   17869.77    1305.04
# UVAN       6768.0     เกษตรและอุตสาหกรรมอาหาร    1066.79    1123.18
# ACC       1839.99                    ทรัพยากร     203.64     507.66
# VIH       5193.06                      บริการ     686.75     543.52
# GPI        1050.0                      บริการ     150.67     150.54
# UMI       1497.34  อสังหาริมทรัพย์และก่อสร้าง     346.67     108.45
# UPOIC     2284.55     เกษตรและอุตสาหกรรมอาหาร     284.72      81.59
# TAPAC     1301.49  อสังหาริมทรัพย์และก่อสร้าง     294.21      49.55
# RJH       10425.0                      บริการ    1133.62     115.28
# GYT        1295.0            สินค้าอุตสาหกรรม      49.67    1075.92
# TOP     127887.09                    ทรัพยากร   43889.47   40795.36
# BANPU   109058.68                    ทรัพยากร   40981.16   52680.91
# IMH        2386.5                      บริการ     226.72     140.15
# KYE        6296.4          สินค้าอุปโภคบริโภค     431.05    1001.76
# PTTEP    762237.2                    ทรัพยากร  115956.50  130249.39
# BCP      46126.93                    ทรัพยากร   21251.79   34543.75
# SFP        2541.0     เกษตรและอุตสาหกรรมอาหาร     324.66      75.47
# AMATAV    6965.75  อสังหาริมทรัพย์และก่อสร้าง    1264.79    1770.76
# BCH      46882.46                      บริการ    4272.25    1618.27
# BRI       8101.65  อสังหาริมทรัพย์และก่อสร้าง     932.28     579.02
# NER      10994.35     เกษตรและอุตสาหกรรมอาหาร    1509.79     308.42
# SKN        4000.0  อสังหาริมทรัพย์และก่อสร้าง     423.43     622.58
# CHG       40480.0                      บริการ    2867.87    1281.43
# CPH        1470.0          สินค้าอุปโภคบริโภค     180.36      95.30
#
#         totalasset  liability_current  liability_total        ey       roc  \
# NATION     1304.01             237.50           141.69  0.529111  0.522349
# RCL       54337.64             205.84          4309.17    1.3894  0.290109
# LANNA     14790.25             294.38          1291.60  0.579576  0.319962
# ECF         656.66             239.87            26.48  0.399976  0.402961
# CHOW       5023.12             432.51           233.26  0.475459  0.296011
# BTNC        112.13             120.00             7.73  0.142435  1.653113
# ESSO      93854.36            5333.73          6177.01  0.322556  0.201871
# UVAN       5107.65             552.52           849.18  0.164273  0.234195
# ACC         832.25              44.37            71.12    0.1451  0.258466
# VIH        3744.40              98.04           208.91  0.141352  0.188339
# GPI         995.58             139.65           164.74  0.141581  0.176031
# UMI        2819.29              72.51           365.81  0.197567  0.126210
# UPOIC      1715.05              36.67           124.15  0.122349  0.169640
# TAPAC      2469.19              26.19           162.64  0.207984  0.120430
# RJH        4316.09            1085.22          1592.44  0.095245  0.350871
# GYT         147.48              74.00           351.65  0.087029  0.675966
# TOP      443278.08           30408.68        172068.50  0.169353  0.106304
# BANPU    432065.70           33369.05        196180.49  0.162264  0.102788
# IMH        1110.99             102.12           274.99   0.08992  0.224727
# KYE         828.96             -79.89            -2.02  0.081444  0.474281
# PTTEP    935677.60          102683.17        440572.63  0.108112  0.139204
# BCP      231913.57           11627.90         92692.89  0.203803  0.096474
# SFP        2753.76             823.57           931.79  0.095564  0.168201
# AMATAV    13311.98            1025.68          3745.64  0.141465  0.102943
# BCH       24842.49            2264.69          2965.69  0.088581  0.189223
# BRI       10028.61            1280.27           235.14  0.120174  0.106567
# NER       13533.15              93.80          2299.48  0.116268  0.112341
# SKN        4227.59              40.99           246.31  0.116849  0.101139
# CHG       10645.99              65.00           505.84  0.072231  0.271040
# CPH        1853.50               3.75           139.15   0.11914  0.097505
#
#         ey_score  roc_score  magic_score
# NATION         5          6           11
# RCL            1         14           15
# LANNA          4         11           15
# ECF            7          8           15
# CHOW           6         13           19
# BTNC          22          2           24
# ESSO           8         24           32
# UVAN          16         19           35
# ACC           20         17           37
# VIH           25         28           53
# GPI           23         31           54
# UMI           12         47           59
# UPOIC         30         32           62
# TAPAC         10         52           62
# RJH           56          9           65
# GYT           64          4           68
# TOP           15         60           75
# BANPU         17         65           82
# IMH           60         22           82
# KYE           76          7           83
# PTTEP         43         41           84
# BCP           11         76           87
# SFP           55         33           88
# AMATAV        24         64           88
# BCH           62         27           89
# BRI           31         59           90
# NER           35         56           91
# SKN           34         67          101
# CHG           87         15          102
# CPH           32         74          106
# Top 30 stocks in magic formula are:
# ['NATION', 'RCL', 'LANNA', 'ECF', 'CHOW', 'BTNC', 'ESSO', 'UVAN', 'ACC', 'VIH', 'GPI', 'UMI', 'UPOIC', 'TAPAC', 'RJH', 'GYT', 'TOP', 'BANPU', 'IMH', 'KYE', 'PTTEP', 'BCP', 'SFP', 'AMATAV', 'BCH', 'BRI', 'NER', 'SKN', 'CHG', 'CPH']
